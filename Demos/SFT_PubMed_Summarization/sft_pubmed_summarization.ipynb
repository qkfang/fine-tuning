# %% [markdown]
# # Supervised Fine-Tuning with PubMed Dataset on Microsoft Foundry
#
# This notebook demonstrates how to fine-tune language models using **Supervised Fine-Tuning (SFT)** with the PubMed Medical Research Summarization dataset.
#
# ## What You'll Learn
# 1. Understand supervised fine-tuning for medical text summarization
# 2. Prepare and format medical research data
# 3. Upload datasets to Microsoft Foundry
# 4. Create and monitor a supervised fine-tuning job
# 5. Deploy and test your fine-tuned model
#
# **Note**: Execute each cell in sequence.

# %% [markdown]
# ## 1. Setup and Installation
#
# Install all required packages from requirements.txt

# %%
pip install -r requirements.txt
# Out:
# Requirement already satisfied: azure-ai-projects>=2.0.0b1 in c:\python\python312\lib\site-packages (from -r requirements.txt (line 2)) (2.0.0)
# Requirement already satisfied: openai in c:\python\python312\lib\site-packages (from -r requirements.txt (line 5)) (2.15.0)
# Requirement already satisfied: azure-identity in c:\python\python312\lib\site-packages (from -r requirements.txt (line 8)) (1.19.0)
# Requirement already satisfied: azure-mgmt-cognitiveservices in c:\python\python312\lib\site-packages (from -r requirements.txt (line 9)) (14.1.0)
# Requirement already satisfied: python-dotenv in c:\python\python312\lib\site-packages (from -r requirements.txt (line 12)) (1.2.1)
# Requirement already satisfied: isodate>=0.6.1 in c:\python\python312\lib\site-packages (from azure-ai-projects>=2.0.0b1->-r requirements.txt (line 2)) (0.7.2)
# Requirement already satisfied: azure-core>=1.37.0 in c:\python\python312\lib\site-packages (from azure-ai-projects>=2.0.0b1->-r requirements.txt (line 2)) (1.38.0)
# Requirement already satisfied: typing-extensions>=4.11 in c:\python\python312\lib\site-packages (from azure-ai-projects>=2.0.0b1->-r requirements.txt (line 2)) (4.15.0)
# Requirement already satisfied: azure-storage-blob>=12.15.0 in c:\python\python312\lib\site-packages (from azure-ai-projects>=2.0.0b1->-r requirements.txt (line 2)) (12.28.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\python\python312\lib\site-packages (from openai->-r requirements.txt (line 5)) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\python\python312\lib\site-packages (from openai->-r requirements.txt (line 5)) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\python\python312\lib\site-packages (from openai->-r requirements.txt (line 5)) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\python\python312\lib\site-packages (from openai->-r requirements.txt (line 5)) (0.13.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\python\python312\lib\site-packages (from openai->-r requirements.txt (line 5)) (2.12.5)
# Requirement already satisfied: sniffio in c:\python\python312\lib\site-packages (from openai->-r requirements.txt (line 5)) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\python\python312\lib\site-packages (from openai->-r requirements.txt (line 5)) (4.67.1)
# Requirement already satisfied: cryptography>=2.5 in c:\python\python312\lib\site-packages (from azure-identity->-r requirements.txt (line 8)) (46.0.5)
# Requirement already satisfied: msal>=1.30.0 in c:\python\python312\lib\site-packages (from azure-identity->-r requirements.txt (line 8)) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in c:\python\python312\lib\site-packages (from azure-identity->-r requirements.txt (line 8)) (1.3.1)
# Requirement already satisfied: msrest>=0.7.1 in c:\python\python312\lib\site-packages (from azure-mgmt-cognitiveservices->-r requirements.txt (line 9)) (0.7.1)
# Requirement already satisfied: azure-mgmt-core>=1.6.0 in c:\python\python312\lib\site-packages (from azure-mgmt-cognitiveservices->-r requirements.txt (line 9)) (1.6.0)
# Requirement already satisfied: idna>=2.8 in c:\python\python312\lib\site-packages (from anyio<5,>=3.5.0->openai->-r requirements.txt (line 5)) (3.6)
# Requirement already satisfied: requests>=2.21.0 in c:\python\python312\lib\site-packages (from azure-core>=1.37.0->azure-ai-projects>=2.0.0b1->-r requirements.txt (line 2)) (2.32.5)
# Requirement already satisfied: cffi>=2.0.0 in c:\python\python312\lib\site-packages (from cryptography>=2.5->azure-identity->-r requirements.txt (line 8)) (2.0.0)
# Requirement already satisfied: certifi in c:\python\python312\lib\site-packages (from httpx<1,>=0.23.0->openai->-r requirements.txt (line 5)) (2023.11.17)
# Requirement already satisfied: httpcore==1.* in c:\python\python312\lib\site-packages (from httpx<1,>=0.23.0->openai->-r requirements.txt (line 5)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\python\python312\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai->-r requirements.txt (line 5)) (0.16.0)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in c:\python\python312\lib\site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity->-r requirements.txt (line 8)) (2.10.1)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in c:\python\python312\lib\site-packages (from msrest>=0.7.1->azure-mgmt-cognitiveservices->-r requirements.txt (line 9)) (2.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\python\python312\lib\site-packages (from pydantic<3,>=1.9.0->openai->-r requirements.txt (line 5)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\python\python312\lib\site-packages (from pydantic<3,>=1.9.0->openai->-r requirements.txt (line 5)) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\python\python312\lib\site-packages (from pydantic<3,>=1.9.0->openai->-r requirements.txt (line 5)) (0.4.2)
# Requirement already satisfied: colorama in c:\python\python312\lib\site-packages (from tqdm>4->openai->-r requirements.txt (line 5)) (0.4.6)
# Requirement already satisfied: pycparser in c:\python\python312\lib\site-packages (from cffi>=2.0.0->cryptography>=2.5->azure-identity->-r requirements.txt (line 8)) (3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\python\python312\lib\site-packages (from requests>=2.21.0->azure-core>=1.37.0->azure-ai-projects>=2.0.0b1->-r requirements.txt (line 2)) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python\python312\lib\site-packages (from requests>=2.21.0->azure-core>=1.37.0->azure-ai-projects>=2.0.0b1->-r requirements.txt (line 2)) (2.1.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\python\python312\lib\site-packages (from requests-oauthlib>=0.5.0->msrest>=0.7.1->azure-mgmt-cognitiveservices->-r requirements.txt (line 9)) (3.3.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## 2. Import Libraries

# %%
import os
from dotenv import load_dotenv
from azure.identity import DefaultAzureCredential
from azure.ai.projects import AIProjectClient
load_dotenv()
print("All libraries imported successfully")
# Out:
# All libraries imported successfully

# %% [markdown]
# ## 3. Configure Azure Environment
#
# Set your Microsoft Foundry Project endpoint and model name. We're using **gpt-4.1** in this example, but you can use other supported GPT models. Copy the file `.env.template` (located in this folder), and save it as file named `.env`. Enter appropriate values for the environment variables used for the job you want to run.
#
# ```
# MICROSOFT_FOUNDRY_PROJECT_ENDPOINT=<your-endpoint>
# MODEL_NAME=gpt-4.1
# AZURE_SUBSCRIPTION_ID=<your-subscription-id>
# AZURE_RESOURCE_GROUP=<your-resource-group>
# AZURE_AOAI_ACCOUNT=<your-foundry-account-name>
# ```

# %%
load_dotenv()

endpoint = os.environ.get("MICROSOFT_FOUNDRY_PROJECT_ENDPOINT")
model_name = os.environ.get("MODEL_NAME")

# Define dataset file paths
training_file_path = "pubmed-training.jsonl"
validation_file_path = "pubmed-validation.jsonl"

# %% [markdown]
# ## 4. Connect to Microsoft Foundry Project
#
# Connect to Microsoft Foundry Project using Azure credential authentication. This initializes the project client and OpenAI client needed for fine-tuning workflows.
#
# **Important**: Ensure you have the **Azure AI User** role assigned to your account for the Microsoft Foundry Project resource.

# %%
credential = DefaultAzureCredential()
project_client = AIProjectClient(endpoint=endpoint, credential=credential)
openai_client = project_client.get_openai_client()

print("Connected to Microsoft Foundry Project")
# Out:
# Connected to Microsoft Foundry Project

# %% [markdown]
# ## 5. Upload Training Files
#
# Upload the training and validation JSONL files to Microsoft Foundry. Each file is assigned a unique ID that will be referenced when creating the fine-tuning job.

# %%
print("Uploading training file...")
with open(training_file_path, "rb") as f:
    train_file = openai_client.files.create(file=f, purpose="fine-tune")
print(f"Training file ID: {train_file.id}")

print("\nUploading validation file...")
with open(validation_file_path, "rb") as f:
    validation_file = openai_client.files.create(file=f, purpose="fine-tune")
print(f"Validation file ID: {validation_file.id}")
# Out:
# Uploading training file...
# Training file ID: file-e8f397d2ff4941de83c32caacb167628
#
# Uploading validation file...
# Validation file ID: file-66f9b9d076814338895a97c6bdc35d64

# %% [markdown]
# ## 6. Wait for File Processing
#
# Microsoft Foundry needs to process the uploaded files before they can be used for fine-tuning.

# %%
print("Waiting for files to be processed...")
openai_client.files.wait_for_processing(train_file.id)
openai_client.files.wait_for_processing(validation_file.id)
print("Files ready!")
# Out:
# Waiting for files to be processed...
# Files ready!

# %% [markdown]
# ## 7. Create Supervised Fine-Tuning Job
#
# Create a supervised fine-tuning job with your uploaded datasets. Configure the following hyperparameters to control the training process:
#
# **Hyperparameters:**
# 1. **n_epochs (3)**: Number of complete passes through the training dataset. More epochs can improve performance but may lead to overfitting. Typical range: 1-10.
# 2. **batch_size (1)**: Number of training examples processed together in each iteration. Smaller batches provide more frequent updates. Typical range: 1-8.
# 3. **learning_rate_multiplier (1.0)**: Scales the default learning rate. Values < 1.0 make training more conservative, while values > 1.0 speed up learning but may cause instability. Typical range: 0.1-2.0.
#
# **Note**: Adjust these based on your dataset size and quality.

# %%
print("Creating supervised fine-tuning job...")

fine_tune_job = openai_client.fine_tuning.jobs.create(
    model="gpt-4.1",
    training_file=train_file.id,
    validation_file=validation_file.id,    
    method={
        "type": "supervised",
        "supervised": {"hyperparameters": {"n_epochs": 3, "batch_size": 1, "learning_rate_multiplier": 1.0}},
    },
    extra_body={"trainingType": "GlobalStandard"},
    suffix="pubmed-summarization"
)

print(f"Fine-tuning job created!")
print(f"Job ID: {fine_tune_job.id}")
print(f"Status: {fine_tune_job.status}")
print(f"Model: {fine_tune_job.model}")
# Out:
# Creating supervised fine-tuning job...
# Fine-tuning job created!
# Job ID: ftjob-40a147b57fd34d72b9148335b21fc998
# Status: pending
# Model: gpt-4.1-2025-04-14

# %% [markdown]
# ## 8. Monitor Training Progress
#
# Track the status of your fine-tuning job. You can view the current status, and recent training events. Training duration varies based on dataset size, model, and hyperparameters - typically ranging from minutes to several hours.

# %%
from types import SimpleNamespace
fine_tune_job = SimpleNamespace(id="ftjob-78d28ad4a0f149e093c14c3b4cc5e4c5")

job_status = openai_client.fine_tuning.jobs.retrieve(fine_tune_job.id)
print(f"Status: {job_status.status}")
# Out:
# Status: succeeded

# %% [markdown]
# ## 9. Retrieve Fine-Tuned Model
#
# After the fine-tuning job succeeded, retrieve the fine-tuned model ID. This ID is required to make inference calls with your customized model.

# %%
completed_job = openai_client.fine_tuning.jobs.retrieve(fine_tune_job.id)

if completed_job.status == "succeeded":
    fine_tuned_model_id = completed_job.fine_tuned_model
    print(f"Fine-tuned Model ID: {fine_tuned_model_id}")
else:
    print(f"Status: {completed_job.status}")
# Out:
# Fine-tuned Model ID: gpt-4.1-2025-04-14.ft-78d28ad4a0f149e093c14c3b4cc5e4c5-pubmed-summarization

# %% [markdown]
# ## 10. Deploy the Fine-Tuned Model
#
# Deploy the fine-tuned model to Azure OpenAI as a deployment endpoint. This step is required before making inference calls. The deployment uses GlobalStandard SKU with 50 capacity.

# %%
from azure.mgmt.cognitiveservices import CognitiveServicesManagementClient
from azure.mgmt.cognitiveservices.models import Deployment, DeploymentProperties, DeploymentModel, Sku

subscription_id = os.environ.get("AZURE_SUBSCRIPTION_ID")
resource_group = os.environ.get("AZURE_RESOURCE_GROUP")
account_name = os.environ.get("AZURE_AOAI_ACCOUNT")

deployment_name = "gpt-4.1-pubmed-ft2"

with CognitiveServicesManagementClient(credential=credential, subscription_id=subscription_id) as cogsvc_client:
    deployment_model = DeploymentModel(format="OpenAI", name=fine_tuned_model_id, version="1")
    deployment_properties = DeploymentProperties(model=deployment_model)
    deployment_sku = Sku(name="GlobalStandard", capacity=50)
    deployment_config = Deployment(properties=deployment_properties, sku=deployment_sku)
    
    print(f"Deploying fine-tuned model: {fine_tuned_model_id}")
    deployment = cogsvc_client.deployments.begin_create_or_update(
        resource_group_name=resource_group,
        account_name=account_name,
        deployment_name=deployment_name,
        deployment=deployment_config,
    )
    
    print("Waiting for deployment to complete...")
    deployment.result()

print(f"Model deployment completed: {deployment_name}")
# Out:
# Deploying fine-tuned model: gpt-4.1-2025-04-14.ft-78d28ad4a0f149e093c14c3b4cc5e4c5-pubmed-summarization
# Waiting for deployment to complete...

# %% [markdown]
# ## 11. Test Fine-Tuned Model
#
# Test your fine-tuned model by generating a summary for a sample medical research article.

# %%
from openai import AzureOpenAI

azure_endpoint = f"https://{account_name}.cognitiveservices.azure.com/"

client = AzureOpenAI(
    azure_endpoint=azure_endpoint,
    api_key=credential.get_token("https://cognitiveservices.azure.com/.default").token,
    api_version="2024-12-01-preview"
)

test_article = """Background: Alzheimer's disease (AD) is a progressive neurodegenerative disorder characterized by cognitive decline and memory loss. Recent studies have suggested that neuroinflammation plays a crucial role in disease pathogenesis. Objective: This study investigated the role of microglial activation and inflammatory cytokines in early-stage Alzheimer's disease progression. Methods: We conducted a longitudinal study of 150 patients with mild cognitive impairment (MCI) over 36 months. Cerebrospinal fluid (CSF) samples were analyzed for inflammatory markers including IL-6, TNF-α, and IL-1β. Brain imaging using PET scans assessed microglial activation. Results: Patients who progressed to AD showed significantly elevated levels of IL-6 (p<0.001) and TNF-α (p<0.01) at baseline compared to stable MCI patients. Microglial activation was observed in the hippocampus and entorhinal cortex regions. Multivariate analysis revealed that combined inflammatory markers predicted AD conversion with 78% accuracy. Conclusion: Elevated neuroinflammatory markers and microglial activation in MCI patients are associated with increased risk of progression to Alzheimer's disease, suggesting potential therapeutic targets for early intervention."""

deployment_name = "gpt-4.1-pubmed"
response = client.chat.completions.create(
    model=deployment_name,
    messages=[
        {"role": "system", "content": "You are a medical research summarization assistant."},
        {"role": "user", "content": f"Summarize this medical research article:\n\n{test_article}"}
    ],
    temperature=0.7,
    max_tokens=500
)

print(response.choices[0].message.content)
# Out:
# **Summary:**
#
# This study examined the role of neuroinflammation in the early progression of Alzheimer’s disease (AD) by following 150 patients with mild cognitive impairment (MCI) over 36 months. Researchers measured inflammatory cytokines (IL-6, TNF-α, IL-1β) in cerebrospinal fluid and used PET scans to assess microglial activation in the brain. Patients who converted to AD had significantly higher baseline levels of IL-6 and TNF-α, and showed microglial activation in the hippocampus and entorhinal cortex. A combination of these inflammatory markers predicted progression to AD with 78% accuracy. The findings indicate that elevated neuroinflammatory markers and microglial activation are linked to increased risk of AD, highlighting the potential of targeting neuroinflammation for early intervention.

# %% [markdown]
# ##  Congratulations!
#
# You've successfully fine-tuned a model for medical research summarization using the PubMed dataset!
#
# ### Next Steps:
# 1. **Test with more examples**: Try different medical research articles to evaluate performance
# 2. **Adjust hyperparameters**: Experiment with different epoch counts, batch sizes, or learning rates
# 3. **Deploy to production**: Integrate your fine-tuned model into healthcare applications
# 4. **Fine-tune further**: Use your own medical publications or clinical notes for specialized summarization
# 5. **Explore use cases**: Apply the model to systematic reviews, literature analysis, or clinical decision support
